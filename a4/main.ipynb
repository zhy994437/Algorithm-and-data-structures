# %%
#1
class UnionFind:
    def __init__(self, n):
        self.parent = [i for i in range(n)]
        self.rank = [0] * n

    def find(self, u):
        if u != self.parent[u]:
            self.parent[u] = self.find(self.parent[u])
        return self.parent[u]

    def union(self, u, v):
        root_u = self.find(u)
        root_v = self.find(v)
        if root_u != root_v:
            if self.rank[root_u] > self.rank[root_v]:
                self.parent[root_v] = root_u
            elif self.rank[root_u] < self.rank[root_v]:
                self.parent[root_u] = root_v
            else:
                self.parent[root_v] = root_u
                self.rank[root_u] += 1


def minimal_cost_reconstruction(country, build, destroy):
    n = len(country)
    edges = []

    # Create edges based on existing roads
    for i in range(n):
        for j in range(i + 1, n):
            if country[i][j] == '1':
                edges.append((ord(build[i][j]) - ord('A'), i, j))  # Convert build cost to integer
            else:
                edges.append((ord(destroy[i][j]) - ord('A'), i, j))  # Convert destroy cost to integer

    # Sort edges by cost
    edges.sort()

    # Initialize Union-Find data structure
    uf = UnionFind(n)

    # Kruskal's algorithm for MST
    min_cost = 0
    for cost, u, v in edges:
        if uf.find(u) != uf.find(v):
            uf.union(u, v)
            min_cost += cost

    return min_cost


def main():
    inputs = input().split()
    country = inputs[0].split(',')
    build = inputs[1].split(',')
    destroy = inputs[2].split(',')

    min_cost = minimal_cost_reconstruction(country, build, destroy)
    print(min_cost)


if __name__ == "__main__":
    main()

# %%
#3
class UnionFind:
    def __init__(self, n):
        self.parent = [i for i in range(n)]
        self.rank = [0] * n

    def find(self, u):
        if u != self.parent[u]:
            self.parent[u] = self.find(self.parent[u])
        return self.parent[u]

    def union(self, u, v):
        root_u = self.find(u)
        root_v = self.find(v)
        if root_u != root_v:
            if self.rank[root_u] > self.rank[root_v]:
                self.parent[root_v] = root_u
            elif self.rank[root_u] < self.rank[root_v]:
                self.parent[root_u] = root_v
            else:
                self.parent[root_v] = root_u
                self.rank[root_u] += 1


def minimal_cost_reconstruction(country, build, destroy):
    n = len(country)
    edges = []

    # Create edges based on existing roads
    for i in range(n):
        for j in range(i + 1, n):
            if country[i][j] == '1':
                edges.append((ord(build[i][j]), i, j))  # Convert build cost to integer
            else:
                edges.append((ord(destroy[i][j]), i, j))  # Convert destroy cost to integer

    # Sort edges by cost
    edges.sort()

    # Initialize Union-Find data structure
    uf = UnionFind(n)

    # Kruskal's algorithm for MST
    min_cost = 0
    for cost, u, v in edges:
        if uf.find(u) != uf.find(v):
            uf.union(u, v)
            min_cost += cost

    return min_cost


def main():
    inputs = input().split()
    country = inputs[0].split(',')
    build = inputs[1].split(',')
    destroy = inputs[2].split(',')

    min_cost = minimal_cost_reconstruction(country, build, destroy)
    print(min_cost)


if __name__ == "__main__":
    main()

# %%
#4
class UnionFind:
    def __init__(self, n):
        self.parent = [i for i in range(n)]
        self.rank = [0] * n

    def find(self, u):
        if u != self.parent[u]:
            self.parent[u] = self.find(self.parent[u])
        return self.parent[u]

    def union(self, u, v):
        root_u = self.find(u)
        root_v = self.find(v)
        if root_u != root_v:
            if self.rank[root_u] > self.rank[root_v]:
                self.parent[root_v] = root_u
            elif self.rank[root_u] < self.rank[root_v]:
                self.parent[root_u] = root_v
            else:
                self.parent[root_v] = root_u
                self.rank[root_u] += 1


def minimal_cost_reconstruction(country, build, destroy):
    n = len(country)
    edges = []

    # Create edges based on existing roads
    for i in range(n):
        for j in range(i + 1, n):
            if country[i][j] == '1':
                edges.append((ord(build[i][j]), i, j))  # Convert build cost to integer
            else:
                edges.append((ord(destroy[i][j]), i, j))  # Convert destroy cost to integer

    # Sort edges by cost
    edges.sort()

    # Initialize Union-Find data structure
    uf = UnionFind(n)

    # Kruskal's algorithm for MST
    min_cost = 0
    for cost, u, v in edges:
        if uf.find(u) != uf.find(v):  # Check if nodes belong to different components
            uf.union(u, v)
            min_cost += cost

    return min_cost


def main():
    inputs = input().split()
    country = inputs[0].split(',')
    build = inputs[1].split(',')
    destroy = inputs[2].split(',')

    min_cost = minimal_cost_reconstruction(country, build, destroy)
    print(min_cost)


if __name__ == "__main__":
    main()

# %%
#2
def get_cost(country, build, destroy):
    n = len(country)
    cost = [[float('inf')] * n for _ in range(n)]
    
    # Initialize cost matrix based on existing roads
    for i in range(n):
        for j in range(n):
            if country[i][j] == '1':
                cost[i][j] = ord(destroy[i][j]) - ord('A')
            elif i == j:
                cost[i][j] = 0
                
    # Floyd-Warshall algorithm to find shortest paths
    for k in range(n):
        for i in range(n):
            for j in range(n):
                cost[i][j] = min(cost[i][j], cost[i][k] + cost[k][j])
    
    # Calculate total cost for rebuilding
    total_cost = 0
    for i in range(n):
        for j in range(i + 1, n):
            if country[i][j] == '0':
                total_cost += ord(build[i][j]) - ord('A') + cost[i][j]
    
    return total_cost

# Sample input parsing
inputs = input().split()
country_info = inputs[0].split(',')
build_info = inputs[1].split(',')
destroy_info = inputs[2].split(',')

country = [list(row) for row in country_info]
build = [list(row) for row in build_info]
destroy = [list(row) for row in destroy_info]

result = get_cost(country, build, destroy)
print(result)

# %%
#5
class UnionFind:
    def __init__(self, n):
        self.parent = [i for i in range(n)]
        self.rank = [0] * n

    def find(self, u):
        if u != self.parent[u]:
            self.parent[u] = self.find(self.parent[u])
        return self.parent[u]

    def union(self, u, v):
        root_u = self.find(u)
        root_v = self.find(v)
        if root_u != root_v:
            if self.rank[root_u] > self.rank[root_v]:
                self.parent[root_v] = root_u
            elif self.rank[root_u] < self.rank[root_v]:
                self.parent[root_u] = root_v
            else:
                self.parent[root_v] = root_u
                self.rank[root_u] += 1


def minimal_cost_reconstruction(country, build, destroy):
    n = len(country)
    edges = []

    # Create edges based on existing roads and their costs
    for i in range(n):
        for j in range(i + 1, n):
            if country[i][j] == 1:
                # Add edges for both directions with the same cost
                edges.append((abs(ord(build[i][j]) - ord('A')), i, j))  # 取绝对值
                edges.append((abs(ord(build[i][j]) - ord('A')), j, i))  # 取绝对值
            else:
                # Add edges for both directions with the same cost
                edges.append((abs(ord(destroy[i][j]) - ord('A')), i, j))  # 取绝对值
                edges.append((abs(ord(destroy[i][j]) - ord('A')), j, i))  # 取绝对值

    # Sort edges by cost
    edges.sort()

    uf = UnionFind(n)

    min_cost = 0
    for cost, u, v in edges:
        if uf.find(u) != uf.find(v):
            uf.union(u, v)
            min_cost += cost

    return min_cost


def main():
    inputs = input().split()
    country_info = inputs[0].split(',')
    build_info = inputs[1].split(',')
    destroy_info = inputs[2].split(',')

    country = [[int(char) for char in row] for row in country_info]
    build = [list(row) for row in build_info]
    destroy = [list(row) for row in destroy_info]

    min_cost = minimal_cost_reconstruction(country, build, destroy)
    print(min_cost)


if __name__ == "__main__":
    main()

# %%
#6
class UnionFind:
    def __init__(self, n):
        self.parent = list(range(n))
        self.rank = [0] * n

    def find(self, x):
        if self.parent[x] != x:
            self.parent[x] = self.find(self.parent[x])
        return self.parent[x]

    def union(self, x, y):
        root_x = self.find(x)
        root_y = self.find(y)
        if root_x != root_y:
            if self.rank[root_x] > self.rank[root_y]:
                self.parent[root_y] = root_x
            elif self.rank[root_x] < self.rank[root_y]:
                self.parent[root_x] = root_y
            else:
                self.parent[root_y] = root_x
                self.rank[root_x] += 1

def minimal_cost_reconstruction(country, build, destroy):
    n = len(country)
    edges = []

    # Create edges based on existing roads and their costs
    for i in range(n):
        for j in range(i + 1, n):
            if country[i][j] == 1:
                # Add edges for both directions with the same cost
                edges.append((abs(ord(build[i][j]) - ord('A')), i, j))
                edges.append((abs(ord(build[i][j]) - ord('A')), j, i))
            else:
                # Add edges for both directions with the same cost
                edges.append((abs(ord(destroy[i][j]) - ord('A')), i, j))
                edges.append((abs(ord(destroy[i][j]) - ord('A')), j, i))

    # Sort edges by cost
    edges.sort()

    uf = UnionFind(n)

    min_cost = 0
    for cost, u, v in edges:
        if uf.find(u) != uf.find(v):
            uf.union(u, v)
            min_cost += cost

    return min_cost

def main():
    inputs = input().split()
    country_info = inputs[0].split(',')
    build_info = inputs[1].split(',')
    destroy_info = inputs[2].split(',')

    country = [[int(char) for char in row] for row in country_info]
    build = [list(row) for row in build_info]
    destroy = [list(row) for row in destroy_info]

    min_cost = minimal_cost_reconstruction(country, build, destroy)
    print(min_cost)

if __name__ == "__main__":
    main()

# %%
#7
class UnionFind:
    def __init__(self, n):
        self.parent = [i for i in range(n)]
        self.rank = [0] * n

    def find(self, u):
        if u != self.parent[u]:
            self.parent[u] = self.find(self.parent[u])
        return self.parent[u]

    def union(self, u, v):
        root_u = self.find(u)
        root_v = self.find(v)
        if root_u != root_v:
            if self.rank[root_u] > self.rank[root_v]:
                self.parent[root_v] = root_u
            elif self.rank[root_u] < self.rank[root_v]:
                self.parent[root_u] = root_v
            else:
                self.parent[root_v] = root_u
                self.rank[root_u] += 1

def minimal_cost_reconstruction(country, build, destroy):
    n = len(country)
    edges = []

    # Create edges based on existing roads and potential roads
    for i in range(n):
        for j in range(i + 1, n):
            if country[i][j] == '1':
                # If there's an existing road, consider the cost to destroy
                edges.append((ord(destroy[i][j]) - ord('A'), i, j))
            else:
                # If there's no road, consider the cost to build
                edges.append((ord(build[i][j]) - ord('A'), i, j))

    # Sort edges by cost
    edges.sort()

    # Initialize Union-Find data structure
    uf = UnionFind(n)

    # Kruskal's algorithm for MST
    min_cost = 0
    for cost, u, v in edges:
        if uf.find(u) != uf.find(v):
            uf.union(u, v)
            min_cost += cost

    return min_cost

# Example usage
country = [['0', '1', '1'], ['1', '0', '1'], ['1', '1', '0']]
build = [['A', 'B', 'D'], ['B', 'A', 'C'], ['D', 'C', 'A']]
destroy = [['A', 'B', 'D'], ['B', 'A', 'C'], ['D', 'C', 'A']]
print(minimal_cost_reconstruction(country, build, destroy))  # Output should be the minimal cost

# %%
#8
  class UnionFind:
    def __init__(self, n):
        self.parent = [i for i in range(n)]
        self.rank = [0] * n

    def find(self, u):
        if u != self.parent[u]:
            self.parent[u] = self.find(self.parent[u])
        return self.parent[u]

    def union(self, u, v):
        root_u = self.find(u)
        root_v = self.find(v)
        if root_u != root_v:
            if self.rank[root_u] > self.rank[root_v]:
                self.parent[root_v] = root_u
            elif self.rank[root_u] < self.rank[root_v]:
                self.parent[root_u] = root_v
            else:
                self.parent[root_v] = root_u
                self.rank[root_u] += 1

def parse_input(input_str):
    input_str = input_str.replace(',', '')  # 去掉逗号
    country_str, build_str, destroy_str = input_str.split()  # 按空格拆分
    n = len(country_str) // 3  # 国家矩阵的大小
    country = [[int(country_str[i*n+j]) for j in range(n)] for i in range(n)]  # 解析国家矩阵
    build = [[ord(build_str[i*n+j]) - ord('A') for j in range(n)] for i in range(n)]  # 解析build矩阵
    destroy = [[ord(destroy_str[i*n+j]) - ord('A') for j in range(n)] for i in range(n)]  # 解析destroy矩阵
    return country, build, destroy


def minimal_cost_reconstruction(input_str):
    country, build, destroy = parse_input(input_str)
    n = len(country)
    edges = []

    for i in range(n):
        for j in range(i + 1, n):
            if country[i][j] == 1:
                edges.append((destroy[i][j], i, j))
            else:
                edges.append((build[i][j], i, j))

    edges.sort()

    uf = UnionFind(n)
    min_cost = 0

    for cost, u, v in edges:
        if uf.find(u) != uf.find(v):
            uf.union(u, v)
            min_cost += cost

    return min_cost

# 测试
test_input = '011,101,110 ABD,BAC,DCA ABD,BAC,DCA'

print(minimal_cost_reconstruction(test_input))  # 输出：1

# %%
#9
class UnionFind:
    def __init__(self, n):
        self.parent = [i for i in range(n)]
        self.rank = [0] * n

    def find(self, u):
        if u != self.parent[u]:
            self.parent[u] = self.find(self.parent[u])
        return self.parent[u]

    def union(self, u, v):
        root_u = self.find(u)
        root_v = self.find(v)
        if root_u != root_v:
            if self.rank[root_u] > self.rank[root_v]:
                self.parent[root_v] = root_u
            elif self.rank[root_u] < self.rank[root_v]:
                self.parent[root_u] = root_v
            else:
                self.parent[root_v] = root_u
                self.rank[root_u] += 1


def minimal_cost_reconstruction(country, build, destroy):
    n = len(country)
    edges = []

    # Create edges based on existing roads
    for i in range(n):
        for j in range(i + 1, n):
            if country[i][j] == '1':
                edges.append((ord(build[i][j]) - ord('A'), i, j))  # Convert build cost to integer
            else:
                edges.append((ord(destroy[i][j]) - ord('A'), i, j))  # Convert destroy cost to integer

    # Sort edges by cost
    edges.sort()

    # Initialize Union-Find data structure
    uf = UnionFind(n)

    # Kruskal's algorithm for MST
    min_cost = 0
    for cost, u, v in edges:
        if uf.find(u) != uf.find(v):
            uf.union(u, v)
            min_cost += cost

    return min_cost


def main():
    inputs = input().split()
    country = inputs[0].split(',')
    build = inputs[1].split(',')
    destroy = inputs[2].split(',')

    min_cost = minimal_cost_reconstruction(country, build, destroy)
    print(min_cost)


if __name__ == "__main__":
    main()

# %%
#10
class UnionFind:
    def __init__(self, n):
        self.parent = [i for i in range(n)]
        self.rank = [0] * n

    def find(self, u):
        if u != self.parent[u]:
            self.parent[u] = self.find(self.parent[u])
        return self.parent[u]

    def union(self, u, v):
        root_u = self.find(u)
        root_v = self.find(v)
        if root_u != root_v:
            if self.rank[root_u] > self.rank[root_v]:
                self.parent[root_v] = root_u
            elif self.rank[root_u] < self.rank[root_v]:
                self.parent[root_u] = root_v
            else:
                self.parent[root_v] = root_u
                self.rank[root_u] += 1


def minimal_cost_reconstruction(country, build, destroy):
    n = len(country)
    edges = []

    # Create edges based on existing roads
    for i in range(n):
        for j in range(i + 1, n):
            if country[i][j] == '1':
                edges.append((ord(destroy[i][j]) - ord('A'), i, j))  # Convert destroy cost to integer
            else:
                edges.append((ord(build[i][j]) - ord('A'), i, j))  # Convert build cost to integer

    # Sort edges by cost
    edges.sort()

    # Initialize Union-Find data structure
    uf = UnionFind(n)

    # Kruskal's algorithm for MST
    min_cost = 0
    for cost, u, v in edges:
        if uf.find(u) != uf.find(v):
            uf.union(u, v)
            min_cost += cost

    return min_cost


def main():
    inputs = input().split()
    country = inputs[0].split(',')
    build = inputs[1].split(',')
    destroy = inputs[2].split(',')

    min_cost = minimal_cost_reconstruction(country, build, destroy)
    print(min_cost)


if __name__ == "__main__":
    main()

# %%
#11
class UnionFind:
    def __init__(self, n):
        self.parent = [i for i in range(n)]
        self.rank = [0] * n

    def find(self, u):
        if u != self.parent[u]:
            self.parent[u] = self.find(self.parent[u])
        return self.parent[u]

    def union(self, u, v):
        root_u = self.find(u)
        root_v = self.find(v)
        if root_u != root_v:
            if self.rank[root_u] > self.rank[root_v]:
                self.parent[root_v] = root_u
            elif self.rank[root_u] < self.rank[root_v]:
                self.parent[root_u] = root_v
            else:
                self.parent[root_v] = root_u
                self.rank[root_u] += 1
            return True
        return False

# Function to convert costs from letters to integers
def cost_to_int(cost):
    if cost.isupper():
        return ord(cost) - ord('A')
    return ord(cost) - ord('a') + 26

# Main function for reconstructing the road system with minimal cost
def minimal_cost_reconstruction(country, build, destroy):
    n = len(country)
    edges = []

    # Create edges with the corresponding build or destroy cost
    for i in range(n):
        for j in range(i + 1, n):
            if country[i][j] == '1':
                # If there is a road, consider the destroying cost (subtract)
                edges.append((-cost_to_int(destroy[i][j]), i, j))
            else:
                # If there is no road, consider the building cost (add)
                edges.append((cost_to_int(build[i][j]), i, j))

    # Sort edges based on the absolute value of cost
    edges.sort(key=lambda x: abs(x[0]))

    # Initialize Union-Find for Kruskal's algorithm
    uf = UnionFind(n)

    # Calculate minimum cost to achieve a MST
    min_cost = 0
    for cost, u, v in edges:
        if uf.union(u, v):
            min_cost += cost

    return abs(min_cost)  # The cost might be negative, so take the absolute value

# Function to parse input strings into arrays
def parse_input_matrix(input_string):
    return [list(row) for row in input_string.split(',')]

# Test cases (already provided in the PDF document)
if __name__ == "__main__":
    # Test Case 2
    country = parse_input_matrix("011,101,110")
    build = parse_input_matrix("ABD,BAC,DCA")
    destroy = parse_input_matrix("ABD,BAC,DCA")
    print(minimal_cost_reconstruction(country, build, destroy))  # Expected Output: 1

    # Additional test cases...

# %%
#12
class UnionFind:
    def __init__(self, n):
        self.parent = [i for i in range(n)]
        self.rank = [0] * n

    def find(self, u):
        if u != self.parent[u]:
            self.parent[u] = self.find(self.parent[u])
        return self.parent[u]

    def union(self, u, v):
        root_u = self.find(u)
        root_v = self.find(v)
        if root_u != root_v:
            if self.rank[root_u] > self.rank[root_v]:
                self.parent[root_v] = root_u
            elif self.rank[root_u] < self.rank[root_v]:
                self.parent[root_u] = root_v
            else:
                self.parent[root_v] = root_u
                self.rank[root_u] += 1

def convert_cost(c):
    if 'A' <= c <= 'Z':
        return ord(c) - ord('A')
    if 'a' <= c <= 'z':
        return ord(c) - ord('a') + 26
    return float('inf')  # In case of invalid character

def minimal_cost_reconstruction(country, build, destroy):
    n = len(country)
    edges = []

    # Create edges based on existing roads
    for i in range(n):
        for j in range(n):
            if i != j:
                if country[i][j] == '1':
                    cost = -convert_cost(destroy[i][j])  # Use negative cost for destruction
                else:
                    cost = convert_cost(build[i][j])  # Use positive cost for construction
                edges.append((cost, i, j))

    # Sort edges by cost
    edges.sort()

    # Initialize Union-Find data structure
    uf = UnionFind(n)

    # Kruskal's algorithm for MST
    min_cost = 0
    for cost, u, v in edges:
        if uf.find(u) != uf.find(v):
            uf.union(u, v)
            min_cost += cost

    # Since destruction costs were negative, we subtract from the total cost
    return -min_cost

def main():
    inputs = input().split()
    country = inputs[0].split(',')
    build = inputs[1].split(',')
    destroy = inputs[2].split(',')

    min_cost = minimal_cost_reconstruction(country, build, destroy)
    print(min_cost)

if __name__ == "__main__":
    main()

# %%
#13
class UnionFind:
    def __init__(self, n):
        self.parent = [i for i in range(n)]
        self.rank = [0] * n

    def find(self, u):
        if u != self.parent[u]:
            self.parent[u] = self.find(self.parent[u])
        return self.parent[u]

    def union(self, u, v):
        root_u = self.find(u)
        root_v = self.find(v)
        if root_u != root_v:
            if self.rank[root_u] > self.rank[root_v]:
                self.parent[root_v] = root_u
            elif self.rank[root_u] < self.rank[root_v]:
                self.parent[root_u] = root_v
            else:
                self.parent[root_v] = root_u
                self.rank[root_u] += 1

def char_to_cost(c):
    if 'A' <= c <= 'Z':
        return ord(c) - ord('A')
    elif 'a' <= c <= 'z':
        return ord(c) - ord('a') + 26
    return 0

def minimal_cost_reconstruction(country, build, destroy):
    n = len(country)
    edges = []

    
    for i in range(n):
        for j in range(i + 1, n):
            if country[i][j] == '1':
                destroy_cost = -char_to_cost(destroy[i][j])
                edges.append((destroy_cost, i, j))
            else:
                build_cost = char_to_cost(build[i][j])
                edges.append((build_cost, i, j))

    
    edges.sort(key=lambda x: (abs(x[0]), x[0]))

    
    uf = UnionFind(n)

    
    min_cost = 0
    for cost, u, v in edges:
        if uf.find(u) != uf.find(v):
            uf.union(u, v)
            min_cost += abs(cost)  

    return min_cost

def parse_input_matrix(input_string):
    return [list(row) for row in input_string.split(',')]

def main():
    inputs = input().split()
    country = parse_input_matrix(inputs[0])
    build = parse_input_matrix(inputs[1])
    destroy = parse_input_matrix(inputs[2])

    min_cost = minimal_cost_reconstruction(country, build, destroy)
    print(min_cost)

if __name__ == "__main__":
    main()

# %%
class UnionFind:
    def __init__(self, n):
        self.parent = [i for i in range(n)]
        self.rank = [0] * n

    def find(self, u):
        if u != self.parent[u]:
            self.parent[u] = self.find(self.parent[u])
        return self.parent[u]

    def union(self, u, v):
        root_u = self.find(u)
        root_v = self.find(v)
        if root_u != root_v:
            if self.rank[root_u] > self.rank[root_v]:
                self.parent[root_v] = root_u
            elif self.rank[root_u] < self.rank[root_v]:
                self.parent[root_u] = root_v
            else:
                self.parent[root_v] = root_u
                self.rank[root_u] += 1

def char_to_cost(c):
    if 'A' <= c <= 'Z':
        return ord(c) - ord('A')
    elif 'a' <= c <= 'z':
        return ord(c) - ord('a') + 26
    return 0

def minimal_cost_reconstruction(country, build, destroy):
    n = len(country)
    edges = []

    
    for i in range(n):
        for j in range(i + 1, n):
            if country[i][j] == '1':
                destroy_cost = -char_to_cost(destroy[i][j])
                edges.append((destroy_cost, i, j))
            else:
                build_cost = char_to_cost(build[i][j])
                edges.append((build_cost, i, j))

    
    edges.sort(key=lambda x: (abs(x[0]), x[0]))

    
    uf = UnionFind(n)

    
    min_cost = 0
    for cost, u, v in edges:
        if uf.find(u) != uf.find(v):
            uf.union(u, v)
            min_cost += abs(cost)  

    return min_cost

def parse_input_matrix(input_string):
    return [list(row) for row in input_string.split(',')]

def main():
    inputs = input().split()
    country = parse_input_matrix(inputs[0])
    build = parse_input_matrix(inputs[1])
    destroy = parse_input_matrix(inputs[2])

    min_cost = minimal_cost_reconstruction(country, build, destroy)
    print(min_cost)

if __name__ == "__main__":
    main()

# %%
class UnionFind:
    def __init__(self, n):
        self.parent = [i for i in range(n)]
        self.rank = [0] * n

    def find(self, u):
        if u != self.parent[u]:
            self.parent[u] = self.find(self.parent[u])
        return self.parent[u]

    def union(self, u, v):
        root_u = self.find(u)
        root_v = self.find(v)
        if root_u != root_v:
            if self.rank[root_u] > self.rank[root_v]:
                self.parent[root_v] = root_u
            elif self.rank[root_u] < self.rank[root_v]:
                self.parent[root_u] = root_v
            else:
                self.parent[root_v] = root_u
                self.rank[root_u] += 1

def char_to_cost(c):
    if 'A' <= c <= 'Z':
        return ord(c) - ord('A')
    elif 'a' <= c <= 'z':
        return ord(c) - ord('a') + 26
    return 0

def minimal_cost_reconstruction(country, build, destroy):
    n = len(country)
    edges = []

    # Create edges based on existing roads and new roads
    for i in range(n):
        for j in range(i + 1, n):
            if country[i][j] == '1':
                destroy_cost = -char_to_cost(destroy[i][j])
                edges.append((destroy_cost, i, j))
            else:
                build_cost = char_to_cost(build[i][j])
                edges.append((build_cost, i, j))

    # Sort edges by absolute cost
    edges.sort(key=lambda x: (abs(x[0]), x[0]))

    # Initialize Union-Find data structure
    uf = UnionFind(n)

    # Kruskal's algorithm for MST
    mst = [[0] * n for _ in range(n)]
    for cost, u, v in edges:
        if uf.find(u) != uf.find(v):
            uf.union(u, v)
            mst[u][v] = 1
            mst[v][u] = 1

    # Calculate the final cost based on MST and the given country matrix
    final_cost = 0

    for i in range(n):
        for j in range(n):
            if i != j:
                if mst[i][j] == 1 and country[i][j] == '0':
                    final_cost += char_to_cost(build[i][j])
                elif mst[i][j] == 0 and country[i][j] == '1':
                    final_cost += char_to_cost(destroy[i][j])

    return final_cost

def parse_input_matrix(input_string):
    return [list(row) for row in input_string.split(',')]

def main():
    inputs = input().split()
    country = parse_input_matrix(inputs[0])
    build = parse_input_matrix(inputs[1])
    destroy = parse_input_matrix(inputs[2])

    min_cost = minimal_cost_reconstruction(country, build, destroy)
    print(min_cost)

if __name__ == "__main__":
    main()
# Out:
# 011,101,110 ABD,BAC,DCA ABD,BAC,DCA
# 6

# %%
class Disjointset:
    def __init__(self, n):
        self.parent = list(range(n))
        self.rank = [0] * n

    def find(self, x):
        if self.parent[x] != x:
            self.parent[x] = self.find(self.parent[x])
        return self.parent[x]

    def union(self, x, y):
        x_root = self.find(x)
        y_root = self.find(y)
        if x_root == y_root:
            return
        if self.rank[x_root] < self.rank[y_root]:
            self.parent[x_root] = y_root
        elif self.rank[x_root] > self.rank[y_root]:
            self.parent[y_root] = x_root
        else:
            self.parent[y_root] = x_root
            self.rank[x_root] += 1

class Reorganization:
    def cost(self, ch):
        if 'A' <= ch <= 'Z':
            return ord(ch) - ord('A')
        else:
            return ord(ch) - ord('a') + 26

    def getcost(self, kingdom, build, destroy):
        n = len(kingdom)
        E1, E2 = [], []
        for i in range(n):
            for j in range(i):
                if kingdom[i][j] == '1':
                    E1.append((i, j, self.cost(destroy[i][j])))
                else:
                    E2.append((i, j, self.cost(build[i][j])))
        E1.sort(key=lambda x: (-x[2], x[0], x[1]))
        E2.sort(key=lambda x: (x[2], x[0], x[1]))

        ds = Disjointset(n)
        cost = 0
        for u, v, w in E1:
            if ds.find(u) != ds.find(v):
                ds.union(u, v)
            else:
                cost += w
        for u, v, w in E2:
            if ds.find(u) != ds.find(v):
                ds.union(u, v)
                cost += w
        return cost

def parse_inputmatrix(input_str):
    rows = input_str.strip("[]").split(",")
    matrix = [row.strip("'") for row in rows]
    return matrix

def main():
    inputs = input().split()
    kingdom = parse_inputmatrix(inputs[0])
    build = parse_inputmatrix(inputs[1])
    destroy = parse_inputmatrix(inputs[2])

    solver = Reorganization()
    min_cost = solver.getcost(kingdom, build, destroy)
    print(min_cost)

if __name__ == "__main__":
    main()
# Out:
# 011,101,110 ABD,BAC,DCA ABD,BAC,DCA
# 1
